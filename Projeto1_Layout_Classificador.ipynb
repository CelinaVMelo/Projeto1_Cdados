# %% [markdown]
# # Projeto 1 - Ciência dos Dados

# %% [markdown]
# Nome: Breno Alencar Araújo
#
# Nome: Celina Vieira de Melo

# %% [markdown]
# Atenção: Serão permitidos grupos de três pessoas, mas com uma rubrica mais exigente. Grupos deste tamanho precisarão fazer um questionário de avaliação de trabalho em equipe

# %% [markdown]
# ___
# Carregando algumas bibliotecas:

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\Breno Alencar\Documents\Insper\Semestre 2\CDados\proj2copia2

# %% [markdown]
# Carregando a base de dados com os tweets classificados como relevantes e não relevantes:

# %%
filename = 'Windows 10_final.xlsx'

# %% [markdown]
# No projeto 1 escolhemos a marca Windows 10 para fazer a análise dos Tweets para a empresa! Com isso, classificamos como relevante os Tweets que estavam relacionados as opiniões dos usuários em relação ao produto e como irrelevantes anúncios, links para correção de erros do Windows etc.

# %%
#Criando Dataframe da planilha Treinamento
train = pd.read_excel(filename)
train.head(5)
# Out:
#                                          Treinamento  Relevância
# 0  relógio casio que eu não usava há meses com a ...           1
# 1  rt @pplware: hoje trazemos 3 ferramentas que o...           0
# 2  ct news - 15/03/2021 (windows 10 começa a dar ...           1
# 3  quer comprar este produto?entao clique neste l...           0
# 4  você ainda pode fazer upgrade gratuito para o ...           1

# %%
#Criando Dataframe da aba Teste da planilha
test = pd.read_excel(filename, sheet_name = 'Teste')
test.head(5)
# Out:
#                                                Teste  Relevância
# 0   um dia eu restauro um windows 10 outro dia um xp           1
# 1  rt @ajulianafiuza: vivendo ou atualizando o wi...           1
# 2  finalmente voltei o meu pc p windows 10 obg se...           1
# 3     @doliveira__ esse aqui https://t.co/fpcbvgkkhj           1
# 4  todo dia esse windows 10 pedindo atualização, ...           1

# %%
#Pd Series de Treinamento
treinamento = pd.Series(train.Treinamento)

# %% [markdown]
# ___
# ## Classificador automático de sentimento

# %% [markdown]
# O Windows 10 é o mais novo sistema operacional da Microsft e desde seu lançamento está rodeado de opiniões díspares.
# Para nosso classificador Naive-Bayes, consideramos como relevantes as constantes atualizações que o sistema passa, o tempo da atualização e o desempenho em jogos, além das experiências dos usuários do sistema.

# %% [markdown]
# ___
# ### Montando um Classificador Naive-Bayes
#
# Considerando apenas as mensagens da planilha Treinamento, ensine  seu classificador.

# %%
import re 

def limpeza(text):
    """
        Função de limpeza que troca alguns sinais básicos por espaços
    """
    #importando string
    punctuation = '[!-.:?;''""@"|"\n"/]' # Sinais [] como delimitadores de um conjunto.
    pattern = re.compile(punctuation)
    text_subbed = re.sub(pattern, '', text)
    return text_subbed

# %%
#Removendo espaços dos Tweets
classifi_0 =' '.join(train.loc[filt_0,'Treinamento'])
classifi_0_limpo = limpeza(classifi_0.lower())

# %%
#Filtrando os Tweets Relevantes e Irrelevantes da aba Treinamento

filt_1 = train.Relevância == 1
classifi_1 =' '.join(train.loc[filt_1,'Treinamento'])


filt_0 = train.Relevância == 0
classifi_0 =' '.join(train.loc[filt_0,'Treinamento'])

#A função .lower() deixa todos os caracteres em minúsculo
classifi_1_limpo = limpeza(classifi_1.lower())

# %%
#Todas as palavras separadas dos tweets Relevantes e Irrelevantes
todas_os_tweets_irrelevantes = classifi_0_limpo.split()

todas_os_tweets_relevantes = classifi_1_limpo.split()
todas_os_tweets_relevantes
#print(len(todas_os_tweets_relevantes))
# Out:
# ['relógio',
#  'casio',
#  'que',
#  'eu',
#  'não',
#  'usava',
#  'há',
#  'meses',
#  'com',
#  'a',
#  'hora',
#  'certinha',
#  'e',
#  'windows',
#  '10',
#  'que',
#  'eu',
#  'uso',
#  'todo',
#  'santo',
#  'dia',
#  'atrasado',
#  '2',
#  'minutos',
#  'bill',
#  'gates',
#  'vc',
#  'perdeu',
#  'ct',
#  'news',
#  '15032021',
#  'windows',
#  '10',
#  'começa',
#  'a',
#  'dar',
#  'tela',
#  'azul',
#  'com',
#  'impressoras',
#  'httpstco4ejai7pldm',
#  'você',
#  'ainda',
#  'pode',
#  'fazer',
#  'upgrade',
#  'gratuito',
#  'para',
#  'o',
#  'windows',
#  '10',
#  'diz',
#  'microsoft',
#  'httpstcoqydzjjk9x8',
#  'httpstcoy3ew0obnuy',
#  'adinezinha',
#  'eu',
#  'pesquisei',
#  'no',
#  'google',
#  'e',
#  'a',
#  'atualização',
#  'é',
#  'muitooo',
#  'grande',
#  'e',
#  'tbm',
#  'vi',
#  'muita',
#  'gente',
#  'reclamando',
#  'que',
#  'tá',
#  'há',
#  'horas',
#  'esperando',
#  'o',
#  'windows',
#  'atualizar',
#  'tbm',
#  'é',
#  'essa',
#  'aquihttpstcozatwglzqzw',
#  'carai',
#  'todo',
#  'dia',
#  'atualização',
#  'do',
#  'windows',
#  '10',
#  'se',
#  'fode',
#  'microsoft',
#  'rt',
#  'olhardigital',
#  'novo',
#  'bug',
#  'no',
#  'windows',
#  '10',
#  'foi',
#  'identificado',
#  'nas',
#  'atualizações',
#  'de',
#  'março',
#  'causando',
#  'a',
#  '“tela',
#  'azul',
#  'da',
#  'morte”',
#  'em',
#  'pcs',
#  'com',
#  'impressoras…',
#  'rt',
#  'hugodomcon',
#  '🐱\u200d💻modificar',
#  'iso',
#  'windows',
#  '10',
#  'httpstcopvaxywjtjf',
#  'via',
#  'youtube',
#  'clapiclapiclapi',
#  'pula',
#  'fora',
#  'de',
#  'notes',
#  'basicos',
#  'da',
#  'dell',
#  'nao',
#  'roda',
#  'nada',
#  'com',
#  '4gb',
#  'de',
#  'ram',
#  'pq',
#  'o',
#  'windows',
#  '10',
#  'é',
#  'pesado',
#  'ce',
#  'passa',
#  'raiva',
#  '1tb',
#  'ilude',
#  'muito',
#  'atualização',
#  'do',
#  'windows',
#  '10',
#  'está',
#  'causando',
#  'tela',
#  'azul',
#  'ao',
#  'tentar',
#  'imprimir',
#  'documentos',
#  'httpstcobwjykzvgfg',
#  'formatei',
#  'meu',
#  'pc',
#  'que',
#  'tava',
#  'do',
#  'windows',
#  '10',
#  'voltei',
#  'pro',
#  '7',
#  'basic',
#  'e',
#  'tá',
#  'bem',
#  'mais',
#  'rápido',
#  'nossa',
#  'atualização',
#  'do',
#  'windows',
#  '10',
#  'está',
#  'causando',
#  'tela',
#  'azul',
#  'ao',
#  'tentar',
#  'imprimir',
#  'documentos',
#  'unidospelavacina',
#  'httpstco9ycthiwxfe',
#  'dlwsos',
#  'olá',
#  'érika',
#  '🙂',
#  'as',
#  'atualizações',
#  'através',
#  'do',
#  'windows',
#  'update',
#  'são',
#  'recomendadas',
#  'para',
#  'para',
#  'garantir',
#  'um',
#  'sistema',
#  'mais',
#  'seguro',
#  'e',
#  'com',
#  'melhor',
#  'desempenho',
#  'caso',
#  'precise',
#  'é',
#  'possível',
#  'pausar',
#  'as',
#  'atualizações',
#  'httpstcofaxu1tzcl6',
#  'sem',
#  'condições',
#  'no',
#  'tanto',
#  'que',
#  'o',
#  'áudio',
#  'no',
#  'windows',
#  '10',
#  'é',
#  'ruim',
#  'o',
#  '7',
#  'dava',
#  'um',
#  'pau',
#  'windows',
#  '10',
#  'vai',
#  'tomar',
#  'no',
#  'cu',
#  'ct',
#  'news',
#  '15032021',
#  'windows',
#  '10',
#  'começa',
#  'a',
#  'dar',
#  'tela',
#  'azul',
#  'com',
#  'impressoras',
#  'httpstcodmm6wslss7',
#  'httpstcoaaesbx9q6s',
#  'futuras',
#  'versões',
#  'do',
#  'windows',
#  '10',
#  'vão',
#  'deixar',
#  'de',
#  'lado',
#  'certas',
#  'apps',
#  'préinstaladashttpstcob4bdyzeu0pmicrosoft',
#  'httpstcov3l0yad0bs',
#  'rt',
#  'tecnoblog',
#  'windows',
#  '10',
#  'é',
#  'atualizado',
#  'para',
#  'resolver',
#  'bug',
#  'de',
#  'tela',
#  'azul',
#  'da',
#  'morte',
#  'httpstcouuub5roiof',
#  'vivendo',
#  'ou',
#  'atualizando',
#  'o',
#  'windows',
#  '10',
#  'desgraça',
#  'de',
#  'windows',
#  '10',
#  'q',
#  'tem',
#  'atualização',
#  'todo',
#  'dia',
#  'madeiradez',
#  'olha',
#  'não',
#  'sei',
#  'se',
#  'tem',
#  'a',
#  'mesma',
#  'relação',
#  'mas',
#  'meu',
#  'desktop',
#  'atualizou',
#  'ontem',
#  'e',
#  'hj',
#  'não',
#  'conseguia',
#  'acessar',
#  'a',
#  'internet',
#  'daí',
#  'fui',
#  'procurar',
#  'no',
#  'google',
#  'e',
#  'vi',
#  'q',
#  'o',
#  'windows',
#  '10',
#  'tá',
#  'fazendo',
#  'isso',
#  'fiz',
#  'um',
#  'procedimento',
#  'p',
#  'restaurar',
#  'redes',
#  'e',
#  'conectou',
#  'você',
#  'ainda',
#  'pode',
#  'fazer',
#  'upgrade',
#  'gratuito',
#  'para',
#  'o',
#  'windows',
#  '10',
#  'diz',
#  'microsoft',
#  'httpstcob4zef90aop',
#  'arkouda_lykos',
#  'pior',
#  'de',
#  'tudo',
#  'é',
#  'que',
#  'não',
#  'é',
#  'kkkkkkkkkkkkkk',
#  'acho',
#  'que',
#  'no',
#  'windows',
#  '7',
#  'ou',
#  '81',
#  'da',
#  'pra',
#  'isso',
#  'ocorrer',
#  'mas',
#  'acho',
#  'que',
#  'no',
#  '10',
#  'desabilitaram',
#  'isso',
#  'guilhox',
#  'pois',
#  'é',
#  'o',
#  'windows',
#  '10',
#  'mesmo',
#  'eu',
#  'uso',
#  'obrigado',
#  'mas',
#  'sei',
#  'la',
#  'acho',
#  'que',
#  'vale',
#  'a',
#  'pena',
#  'se',
#  'preocupar',
#  'um',
#  'pouquinho',
#  'com',
#  'a',
#  'privacidade',
#  'na',
#  'medida',
#  'do',
#  'cômodo',
#  'e',
#  'do',
#  'possível',
#  'mesmo',
#  'tbm',
#  'pq',
#  'eu',
#  'acho',
#  'que',
#  'existe',
#  'uma',
#  'certa',
#  'simbiose',
#  'entre',
#  'privacidade',
#  'e',
#  'segurança',
#  'online',
#  'to',
#  'chumbando',
#  'windows',
#  '10',
#  'num',
#  'notebook',
#  'de',
#  '2011',
#  'que',
#  'deus',
#  'tenha',
#  'piedade',
#  'da',
#  'minha',
#  'alma',
#  'nayaraagain',
#  'há',
#  'algum',
#  'tempo',
#  'utilizo',
#  'um',
#  'programa',
#  'que',
#  'impede',
#  'essas',
#  'surpresas',
#  'que',
#  'costumam',
#  'aparecer',
#  'nas',
#  'horas',
#  'que',
#  'a',
#  'gente',
#  'mais',
#  'precisa',
#  'do',
#  'computador',
#  'pode',
#  'ser',
#  'que',
#  'você',
#  'ache',
#  'interessante',
#  'a',
#  'opção',
#  'de',
#  'fazer',
#  'as',
#  'atualizações',
#  'qnd',
#  'quiser',
#  'fica',
#  'a',
#  'dica',
#  'httpstco2kp7tefjop',
#  'odeio',
#  'essas',
#  'atualizações',
#  'do',
#  'windows',
#  '10',
#  'parece',
#  'q',
#  'n',
#  'tem',
#  'fim',
#  'windows',
#  '10',
#  'é',
#  'o',
#  'sistema',
#  'que',
#  'tem',
#  'tudo',
#  'pra',
#  'dar',
#  'certo',
#  'mas',
#  'consegue',
#  'dar',
#  'errado',
#  'pq',
#  'pqp',
#  'que',
#  'sistema',
#  'fudido',
#  'windows',
#  '10',
#  'é',
#  'atualizado',
#  'para',
#  'resolver',
#  'bug',
#  'de',
#  'tela',
#  'azul',
#  'da',
#  'morte',
#  'httpstcouuub5roiof',
#  'slow',
#  'damage',
#  'me',
#  'fazendo',
#  'migrar',
#  'pro',
#  'windows',
#  '10',
#  'httpstcoqrgxzf1el7',
#  'microsoft',
#  'lança',
#  'solução',
#  'temporária',
#  'para',
#  'bug',
#  'no',
#  'windows',
#  '10',
#  'que',
#  'causa',
#  'tela',
#  'azul',
#  'da',
#  'morte',
#  'ao',
#  'usar',
#  'impressora',
#  'httpstcofamp7xs5iq',
#  'via',
#  'tudo_celular',
#  'guilhox',
#  'tecnicamente',
#  'tem',
#  'isso',
#  'mesmo',
#  'mas',
#  'na',
#  'prática',
#  'a',
#  'gente',
#  'sabe',
#  'que',
#  'ninguém',
#  'lê',
#  'os',
#  'termos',
#  'e',
#  'isso',
#  'de',
#  'só',
#  'migrar',
#  'pra',
#  'outro',
#  'tbm',
#  'é',
#  'complicado',
#  'no',
#  'caso',
#  'de',
#  'browser',
#  'ainda',
#  'tem',
#  'mtas',
#  'opções',
#  'mas',
#  'tem',
#  'outros',
#  'que',
#  'não',
#  'tem',
#  'mtas',
#  'alternativas',
#  'dependendo',
#  'do',
#  'uso',
#  'windows',
#  '10',
#  'ou',
#  'androidios',
#  'por',
#  'exemplo',
#  'estou',
#  'me',
#  'sentindo',
#  'muito',
#  'idiota',
#  'idiota',
#  'mesmo',
#  'acabei',
#  'de',
#  'comprar',
#  'uma',
#  'licença',
#  'original',
#  'do',
#  'windows',
#  '10',
#  'pro',
#  'o',
#  'valor',
#  'é',
#  'absurdosou',
#  'contra',
#  'pirataria',
#  'mas',
#  'estou',
#  'muito',
#  'chocada',
#  'com',
#  'esse',
#  'valor',
#  'e',
#  'mais',
#  'ainda',
#  'por',
#  'ter',
#  'pagomicrosoft',
#  'tá',
#  'fora',
#  'da',
#  'realidade',
#  'mesmo',
#  'surreal',
#  'gente',
#  'que',
#  'incrível',
#  'parece',
#  'q',
#  'a',
#  'etec',
#  'deixa',
#  'disponível',
#  'pra',
#  'download',
#  'o',
#  'programa',
#  'pra',
#  'baixar',
#  'o',
#  'windows',
#  '10',
#  'versão',
#  'x64',
#  'jogosquequero',
#  'porque',
#  'a',
#  'interface',
#  'do',
#  'windows',
#  '10',
#  'windows',
#  '10',
#  'recebe',
#  'correção',
#  'temporária',
#  'da',
#  'microsoft',
#  'para',
#  'tela',
#  'azul',
#  'da',
#  'mortehttpstco2rpc4oyuga',
#  'aplicativosesoftware',
#  'microsoft',
#  'windows10',
#  'celestebulau',
#  'exatamente',
#  'o',
#  'chrome',
#  'costuma',
#  'dar',
#  'pau',
#  'pode',
#  'ser',
#  'android',
#  'ou',
#  'ios',
#  'também',
#  'funciona',
#  'com',
#  'o',
#  'mozillamas',
#  'tem',
#  'que',
#  'ser',
#  'windows',
#  '10',
#  'pra',
#  'rodar',
#  'legal',
#  'bampede',
#  'bem',
#  'vindo',
#  'ao',
#  'windows',
#  '10onde',
#  'vc',
#  'da',
#  'um',
#  'clique',
#  'e',
#  'trava',
#  'tudoou',
#  'vc',
#  'inicia',
#  'ele',
#  'e',
#  'o',
#  'uso',
#  'de',
#  'disco',
#  'ja',
#  'ta',
#  'em',
#  '100',
#  'sem',
#  'razao',
#  'nenhumaai',
#  'eu',
#  'amo',
#  'sa',
#  'porraalguem',
#  'me',
#  'mata',
#  '🤡🤡🤡',
#  'httpstcoore1lbwj8n',
#  'dianelli_',
#  'valeu',
#  'a',
#  'pena',
#  'o',
#  'windows',
#  '10',
#  'ta',
#  'por',
#  'um',
#  'fio',
#  'aq',
#  'n',
#  'aguento',
#  'mais',
#  'atualização',
#  'de',
#  'emergência',
#  'do',
#  'windows',
#  '10',
#  'trata',
#  'bsod',
#  'ao',
#  'imprimira',
#  'mais',
#  'recente',
#  'patch',
#  'tuesday',
#  'de',
#  'março',
#  'trouxe',
#  'um',
#  'problema',
#  'grave',
#  'ao',
#  'windows',
#  '10',
#  'deixou',
#  'de',
#  'ser',
#  'possível',
#  'a',
#  'muitos',
#  'utilizadores',
#  'imprimir',
#  'nos',
#  'seus',
#  'computadores',
#  'tendo',
#  'como',
#  'resultado',
#  'um',
#  'anormal',
#  'b…',
#  'httpstco68mtk4pm4q',
#  'httpstcorfzrwenaae',
#  'ct',
#  'news',
#  '15032021',
#  'windows',
#  '10',
#  'começa',
#  'a',
#  'dar',
#  'tela',
#  'azul',
#  'com',
#  'impressoras',
#  'canaltechpodcast',
#  'httpstcomyntedi5qc',
#  'via',
#  'podcastaddict',
#  'httpstcohfickud1up',
#  'windows',
#  '10',
#  'é',
#  'uma',
#  'porra',
#  'mesmo',
#  'microsoftajuda',
#  '20h2esse',
#  'mesmo',
#  'problema',
#  'eu',
#  'já',
#  'desistihttpstcosyz0drb4es',
#  'windows',
#  '10',
#  'nao',
#  'é',
#  'vida',
#  'httpstcoo4g9ovcfua',
#  'depois',
#  'de',
#  '10',
#  'horas',
#  'tentando',
#  'recuperar',
#  'as',
#  'minhas',
#  'anotações',
#  'eu',
#  'descobri',
#  'q',
#  'meu',
#  'pc',
#  'pegou',
#  'um',
#  'vírus',
#  'q',
#  'desativou',
#  'o',
#  'windows',
#  'update',
#  'oq',
#  'fez',
#  'bloquear',
#  'meu',
#  'pacote',
#  'de',
#  'estudante',
#  'por',
#  'segurança',
#  'httpstcobktchyfqzi',
#  'o',
#  'windows',
#  '10',
#  'vai',
#  'acabar',
#  'como',
#  'assim',
#  'eai',
#  'windows',
#  '10',
#  'não',
#  'vai',
#  'parar',
#  'de',
#  'atualizar',
#  'não',
#  'rt',
#  'leakpt',
#  'novo',
#  'windows',
#  '10',
#  'preparese',
#  'para',
#  'a',
#  'maior',
#  'revolução',
#  'da',
#  'microsoft',
#  'httpstcofcfc9oydyl',
#  'httpstcop7m4e3bqlm',
#  'atualizações',
#  'de',
#  'sistemas',
#  'operacionais',
#  'são',
#  'fundamentais',
#  'para',
#  'o',
#  'bom',
#  'funcionamento',
#  'dos',
#  'equipamentos',
#  'porém',
#  'uma',
#  'recente',
#  'para',
#  'o',
#  'windows',
#  '10',
#  'que',
#  'trouxe',
#  'a',
#  'temida',
#  'tela',
#  'azul',
#  'saiba',
#  'mais',
#  'clicando',
#  'em',
#  'httpstco43c9sj5wlm',
#  'o',
#  'windows',
#  '10',
#  'consegue',
#  'gerar',
#  'problemas',
#  'nunca',
#  'antes',
#  'vistos',
#  'por',
#  'mim',
#  'em',
#  '12',
#  'anos',
#  'de',
#  'trabalho',
#  'o',
#  'diagnóstico',
#  'é',
#  'bizarro',
#  'não',
#  'há',
#  'como',
#  'aplicar',
#  'a',
#  'lógica',
#  'nos',
#  'testes',
#  'tela',
#  'azul',
#  'ao',
#  'imprimir',
#  'h61m',
#  'que',
#  'não',
#  'desliga',
#  'atualizações',
#  'em',
#  'horas',
#  'críticas',
#  'é',
#  'um',
#  'inferno',
#  'linux',
#  'vinde',
#  'a',
#  'mim',
#  '🙌',
#  'microsoftajuda',
#  'olá',
#  ...]

# %%
#Criando um pd.serie para todos os Tweets Irrelevantes
serie_tweets_irr = pd.Series(todas_os_tweets_irrelevantes)

#Criando um pd.serie para todos os Tweets Relevantes
serie_tweets_r = pd.Series(todas_os_tweets_relevantes)

# %%
#Criando Tabela de Frequência absoluta dos Tweets Irrelevantes
tabela_tweets_irr = serie_tweets_irr.value_counts()

#Criando Tabela de Frequência absoluta dos Tweets Relevantes
tabela_tweets_r = serie_tweets_r.value_counts()

# %%
tabela_tweets_relativa_irr = serie_tweets_irr.value_counts(True)

# %%
tabela_tweets_relativa_r = serie_tweets_r.value_counts(True)
#len(tabela_tweets_relativa_r)

# %%
tabela_tweets_relativa_r.sum()
# Out:
# 0.9999999999999999

# %%
palavras_tweets = classifi_0_limpo + classifi_1_limpo
# len(palavras_tweets)

#Universo de palavras vindo dos tweets relevantes e irrelevantes da aba treinamento de nossa planilha
palvras_tweets = todas_os_tweets_irrelevantes + todas_os_tweets_relevantes

# %%
todas_os_tweets = palavras_tweets.split()
serie_tweets = pd.Series(todas_os_tweets)

# %%
# tabela_relativo_tweets = serie_tweets.value_counts(True)
tabela_absoluta_tweets = serie_tweets.value_counts()
tabela_absoluta_tweets
# Out:
# windows           291
# 10                256
# o                 181
# de                179
# que               128
#                  ...
# tarefas             1
# r432264🛒acesse      1
# x512jpej228t        1
# desconto            1
# execute             1
# Length: 2111, dtype: int64

# %%
tabela_absoluta_tweets.shape[0]
# Out:
# 2111

# %%
probabilidade_relevante = len(todas_os_tweets_relevantes)/len(todas_os_tweets)
probabilidade_relevante
# Out:
# 0.6376153966515412

# %%
probilidade_irrelevantes = len(todas_os_tweets_irrelevantes)/len(todas_os_tweets)
probilidade_irrelevantes
# Out:
# 0.36254107338444685

# %% [markdown]
# ___
# ### Verificando a performance do Classificador
#
# Agora você deve testar o seu classificador com a base de Testes.

# %%
quantidade_de_tweets = len(test['Teste'])

# %%
frase = (test['Teste'])

# %%
lista = list(frase)

lista_1 = []

j = 0
while j < len(lista):
    lista_1.append(lista[j])
    j+=1
    
frase = lista_1
print(frase)
# Out:
# ['um dia eu restauro um windows 10 outro dia um xp', 'rt @ajulianafiuza: vivendo ou atualizando o windows 10?', 'finalmente voltei o meu pc p windows 10 obg senhor', '@doliveira__ esse aqui https://t.co/fpcbvgkkhj', 'todo dia esse windows 10 pedindo atualização, que droga\n por isso o 7 é o melhor.', 'a raiva que eu tô passando com essa atualização do windows 10 não é brincadeira', 'geralmente esse alguém é um desses 3 aqui:\n\neduardo vasconcelos \nbolsonaro \nwindows 10 https://t.co/7fuz4ogkha', 'merda tenho que att o windows 10 eu não quero essa merda', '@akkarin314 @juniorgalvaomvp @msdevbr hoje quase impossível instalar um pirata tipo eu mesmo o windows já reconhece a chave original na bios... windows 10 só tenho tido problemas com derrepende as thumbs do desktop demorarem a carregar.', '@pitodipaiagames @nerdlendario mas também não vejo que o xbox (console) está disputando com o pc, pois o windows 10 e xcloud hoje estão dentro do ecossistema xbox.', 'windows 10: atualização corrige bug bsod da impressora -&gt; https://t.co/i9qj2r5fhg #windows10 #telaazuldamorte', 'windows 10 é atualizado para resolver bug de tela azul da morte https://t.co/ifqypi1xrs via @tecnoblog', 'windows 10 é atualizado para resolver bug de tela azul da morte https://t.co/1ygufny3ju', '@etdbmm eu tava instalando windows 10\nque\nódio', 'gosto mto do windows 10, mto moderno bonito', 'todo o meu trabalho naquele ssd e windows 10 instalou um att do nada🤦🤦🤦', 'pra quem foi imprimir no windows 10 e deu tela azul 🥴 https://t.co/q6vdb1p9c2', "@clapiclapiclapi clapi eu comprei esse aqui na black friday ano passado: notebook acer aspire 5 a514-53-59qj intel core i5 8gb 256gb ssd 14' windows 10\n\nele é perfeito mas acho que agora já está mais caro", 'atualização do windows 10 é suspensa devido a tela azul da morte | aplicativos e software | tecnoblog https://t.co/suwlqcggtt', 'notebook hp 250 g7 intel core i5 8gb 256gb ssd - 15,6” windows 10\n\nde r$ 5.299,00\npor\nr$ 3.609,05 à vista (5% desc. já calculado.)\nou r$ 3.799,00 em 12x de r$ 316,58 sem juros\n\nhttps://t.co/vzvel5uggt', 'chrome funciona pésimo con la versiom 20h2 de windows 10?', 'windows 10 fica lançando atualização a cada dia pqp', 'microsoft corrige bug no windows 10 que causava tela azul com uso de impressoras https://t.co/nhqawfll8b https://t.co/tkdequmlgq', 'rt @dalcastelbruno: pra quem foi imprimir no windows 10 e deu tela azul 🥴 https://t.co/q6vdb1p9c2', 'novo vídeo no ar windows 10 com disco ssd 100%, 3 comandos que resolvem em definitivo março/2021 | #mundooffice https://t.co/fqvqxqdzbz', 'os computadores com windows 7 , windows 8 8.1 ou windows 10 somente permitido a versão pirata do mesmo piratarear windows não da cadeia ok', 'mandei meu computador pra formatar e ele tava com o windows 10. voltou com o windows 8. eu estou respirando bem fundo pra não matar ngm.', '@clapiclapiclapi 4 gb de ram pra windows 10 é complicado', '@losartotti fala assim nao windows 10 e um amorzinho', 'quem ativar o meu windows 10 e corrigir o audio vai ganhar um pix, é bucho!', 'novas versões do sistema deixarão os programas de lado, mas você ainda poderá baixá-los na microsoft store! #tecmundo https://t.co/hefavucsgv', 'um aviso a você usuário do windows 10. \na microsoft lançou uma atualização para o s.o que está dando dor de cabeça para os seus usuários. e os dispositivos estão atualizando e voltando com uma tela de erro. leia o próximo twitter...', 'permaneça produtivo remotamente com microsoft 365 e windows 10 pro.\n\ncotação: https://t.co/sb8q7cc7bh\n\n#dell #delltechnologies #dellemc #xps #xps13 #dellxps #microsoft #microsoft365 #office365 #office #windows #windows10 #windows10pro #integreti #titaniumpartner #laptop #notebook https://t.co/noxapyj0xc', 'mais de 24hs tentando atualizar essa bomba de notebook pro windows 10 20h2 e ainda tá em 88% desde que acordei', 'windows 10 é horrível mesmo viu credo', 'aprenda com esse vídeo tutorial a iniciar o windows 10 em modo de segurança: https://t.co/9e7yb1s ...

# %%
lista_relevante = []
lista_irrelevante = []

for i in frase:
    i = i.split()
    for palavra in i:
        
        probFraseDadoR = 1
        
        if palavra in tabela_tweets_r:
            #j = todas_os_tweets_irrelevantes.index(palavra) 
            probFraseDadoR *= (tabela_tweets_r[palavra] + 1) / ( tabela_absoluta_tweets.shape[0] + len(todas_os_tweets_relevantes) )
            
        else:
            probFraseDadoR *= (0 + 1) / ( tabela_absoluta_tweets.shape[0] + len(todas_os_tweets_relevantes) )
            
                
    lista_relevante.append(probFraseDadoR)
                
for k in frase:
    k = k.split()
    for palavra in k:
        
        probFraseDadoIRR = 1
        
        if palavra in tabela_tweets_irr:
            #k = todas_os_tweets_relevantes.index(palavra)
            probFraseDadoIRR *= (tabela_tweets_irr[palavra] + 1) / ( tabela_absoluta_tweets.shape[0] + len(todas_os_tweets_irrelevantes) )
#            
          
        else: 
            probFraseDadoIRR *= (0 + 1) / ( tabela_absoluta_tweets.shape[0] + len(todas_os_tweets_irrelevantes) )
#             
        
    lista_irrelevante.append(probFraseDadoIRR)

# %%
print(len(lista_relevante))
# Out:
# 208

# %%
print(len(lista_irrelevante))
# Out:
# 208

# %%
test
# Out:
#                                                  Teste  Relevância  \
# 0     um dia eu restauro um windows 10 outro dia um xp           1
# 1    rt @ajulianafiuza: vivendo ou atualizando o wi...           1
# 2    finalmente voltei o meu pc p windows 10 obg se...           1
# 3       @doliveira__ esse aqui https://t.co/fpcbvgkkhj           1
# 4    todo dia esse windows 10 pedindo atualização, ...           1
# ..                                                 ...         ...
# 203  olha, ter um computador com windows 10 sem ssd...           1
# 204  todo o meu trabalho naquele ssd e windows 10 i...           1
# 205  anotar pra não esquecer:\nnunca mais tentar in...           1
# 206  @guilhox pois é, o windows 10 mesmo eu uso obr...           1
# 207  você pode ter o pc com os melhores specs do mu...           1
#
#      Classificador
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
# ..             ...
# 203              1
# 204              1
# 205              1
# 206              1
# 207              1
#
# [208 rows x 3 columns]

# %%
probabilidade_relevante = len(todas_os_tweets_relevantes)/len(todas_os_tweets)
probabilidade_irrelevante = len(todas_os_tweets_irrelevantes)/len(todas_os_tweets)
lista_classificador = []

contador = 0
while contador < len(lista_relevante):
    
    Prob_de_ser_Relevante = probabilidade_relevante*lista_relevante[contador]
    Prob_de_ser_Irrelevante = probabilidade_irrelevante*lista_irrelevante[contador]
    
    if Prob_de_ser_Relevante > Prob_de_ser_Irrelevante:
        lista_classificador.append(1)
    
    else:
        lista_classificador.append(0)
        
    contador +=1
        

test["Classificador"] = lista_classificador
test.head()
# Out:
#                                                Teste  Relevância  \
# 0   um dia eu restauro um windows 10 outro dia um xp           1
# 1  rt @ajulianafiuza: vivendo ou atualizando o wi...           1
# 2  finalmente voltei o meu pc p windows 10 obg se...           1
# 3     @doliveira__ esse aqui https://t.co/fpcbvgkkhj           1
# 4  todo dia esse windows 10 pedindo atualização, ...           1
#
#    Classificador
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
pd.crosstab(test["Relevância"],test["Classificador"],normalize=True)*100
# Out:
# Classificador         0          1
# Relevância
# 0              3.846154  32.692308
# 1              0.000000  63.461538

# %%
tabela_tweets_relativa_r
# Out:
# windows         0.048834
# 10              0.043436
# o               0.032393
# de              0.026503
# que             0.023313
#                   ...
# retornar        0.000245
# fznd            0.000245
# impressoras…    0.000245
# positiva        0.000245
# paz             0.000245
# Length: 1358, dtype: float64

# %%
len(tabela_tweets_irr)
# Out:
# 1069

# %%
len(todas_os_tweets_irrelevantes)
# Out:
# 2318

# %% [markdown]
# ___
# ### Concluindo

# %% [markdown]
# A partir da tabela CrosTab concluímos um acerto de 63,46% dos casos em que marcamos como relevante e um acerto de 3,36% dos casos em que marcamos como irrelevante

# %% [markdown]
# Verdadeiro positivo: 63,46%
# Falso positivo: 32.69%
# Falso negativo: 0.0%
# Verdadeiro negativo: 3.84%
#
# Mais de um terço dos tweets foi classificado como falso positivo devido a fatores como ironia e ambiguidade. Vide exemplo: "nem a existência do windows 10 foi uma ideia tão idiota assim ".

# %% [markdown]
# ___
# ### Qualidade do Classificador a partir de novas separações dos tweets entre Treinamento e Teste
#
# Caso for fazer esse item do Projeto

# %%
precisao_percent = []
train2 = pd.read_excel(filename)
test2 = pd.read_excel(filename, sheet_name='Teste')
train2 = train2.rename(columns={'Treinamento':'Todos'})
test2 = test2.rename(columns={'Teste':'Todos'})
Total = pd.concat([test2,train2])
Total
# Out:
#                                                  Todos  Relevância
# 0     um dia eu restauro um windows 10 outro dia um xp           1
# 1    rt @ajulianafiuza: vivendo ou atualizando o wi...           1
# 2    finalmente voltei o meu pc p windows 10 obg se...           1
# 3       @doliveira__ esse aqui https://t.co/fpcbvgkkhj           1
# 4    todo dia esse windows 10 pedindo atualização, ...           1
# ..                                                 ...         ...
# 295  @microsoftbr @microsoftajuda não consigo ajuda...           1
# 296  você pode ter o pc com os melhores specs do mu...           1
# 297  @clapiclapiclapi esse daqui é um i5, 8gb de ra...           0
# 298  windows 10 recebe correção temporária da micro...           1
# 299  rt @magazinewmti: notebook hp 250 g7 intel cor...           0
#
# [508 rows x 2 columns]

# %%
for i in range(100):

# %% [markdown]
# ___
# ## Aperfeiçoamento:
#
# Os trabalhos vão evoluir em conceito dependendo da quantidade de itens avançados:
#
# * Limpar: \n, :, ", ', (, ), etc SEM remover emojis
# * Corrigir separação de espaços entre palavras e emojis ou entre emojis e emojis
# * Propor outras limpezas e transformações que não afetem a qualidade da informação ou classificação
# * Criar categorias intermediárias de relevância baseadas na probabilidade: ex.: muito relevante, relevante, neutro, irrelevante, muito irrelevante (3 categorias: C, mais categorias conta para B)
# * Explicar por que não posso usar o próprio classificador para gerar mais amostras de treinamento
# * Propor diferentes cenários para Naïve Bayes fora do contexto do projeto
# * Sugerir e explicar melhorias reais com indicações concretas de como implementar (indicar como fazer e indicar material de pesquisa)

# %% [markdown]
# ___
# ## Referências

# %% [markdown]
# [Naive Bayes and Text Classification](https://arxiv.org/pdf/1410.5329.pdf)  **Mais completo**
#
# [A practical explanation of a Naive Bayes Classifier](https://monkeylearn.com/blog/practical-explanation-naive-bayes-classifier/) **Mais simples**
